# %%
import pandas as pd
import numpy as np

# %%
### Task one

# %%
def answer_one():
  # Energy 
  energy_df = pd.read_excel(
  'assets/energy_indicators.xls',
  na_values=[...],
  header=None,
  skiprows=18,
  skipfooter=38,
  usecols=[2,3,4,5],
  names=['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
  )
  
  energy_df['Country'] = energy_df['Country'].replace({
  'United States of America20': 'United States', 
  'United Kingdom of Great Britain and Northern Ireland19': 'United Kingdom',
  'China, Hong Kong Special Administrative Region3': 'Hong Kong',
  'Bolivia (Plurinational State of)': 'Bolivia',
  'Iran (Islamic Republic of)': 'Iran',
  'Micronesia (Federated States of)': 'Micronesia',
  'Sint Maarten (Dutch part)': 'Sint Maarten',
  'Venezuela (Bolivarian Republic of)': 'Venezuela',
  'Falkland Islands (Malvinas)': 'Falkland',
  r'\d+': ''
  }, 
  #inplace=True,
  #regex=True
  )
  
  energy_df['Country'] = energy_df['Country'].replace(r'\d+', '', regex=True)
  energy_df['Energy Supply'].replace('...', np.nan, inplace=True)
  
  to_gigajoules = lambda x: x*1e6
  energy_df['Energy Supply'] = energy_df['Energy Supply'].apply(to_gigajoules)
  energy_df = energy_df.set_index('Country')
  
  # GDP
  gdp_df = pd.read_csv(
  'assets/world_bank.csv',
  skiprows=4,
  index_col=False
  )
  
  gdp_df['Country Name'] = gdp_df['Country Name'].replace({
  'Korea, Rep.': 'South Korea',
  'Iran, Islamic Rep.': 'Iran',
  'Hong Kong SAR, China': 'Hong Kong'
  })
  
  # Sciamgo
  scimen_df = pd.read_excel('assets/scimagojr-3.xlsx')
  merge1 = pd.merge(scimen_df, energy_df, how='inner', left_on='Country', right_on='Country')
  
  merge1 = merge1[merge1.Rank <= 15]
  gdp_df.rename(columns={'Country Name': 'Country'}, inplace=True)

  want = ['Country', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']
  gdp_df = gdp_df[want]
  merge2 = pd.merge(merge1,gdp_df,how="inner",left_on="Country",right_on="Country").set_index("Country")
  return merge2

# %%
df = answer_one()

# %%
df
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# Australia             14       8831               8725      90765
# ...

# %%
### Question 3 ####
# what are:
# - the top 15 countries
# - for average GDP 
# - over the last 10 years?

# return a Series named avgGDP
# - with 15 countries
# - and their average GDP
# - sorted in descending order.

# %%
def agvGDP():
  years = [str(2005+i) for i in range(1, 11)]
  target = df[years]
  return target.apply(np.mean, axis=1).sort_values(ascending=False)

# %%
agvGDP()
# Out:
# Country
# United States         1.536434e+13
# China                 6.348609e+12
# Japan                 5.542208e+12
# Germany               3.493025e+12
# France                2.681725e+12
# United Kingdom        2.487907e+12
# Brazil                2.189794e+12
# Italy                 2.120175e+12
# India                 1.769297e+12
# Canada                1.660647e+12
# Russian Federation    1.565459e+12
# Spain                 1.418078e+12
# Australia             1.164043e+12
# Iran                  4.441558e+11
# dtype: float64

# %%
#### Question 4 ####

# By how much:
# - had the GDP changed 
# - over the 10 year span
# - for the country with the 6th largest average GDP?

# function should return a single number.

# %%
def answer_four():
  want = ["2006","2007","2008","2009","2010","2011","2012","2013","2014","2015"]
  info=answer_one()
  info['avgGDP']=info[want].apply(np.mean,axis = 1)
  info.sort_values(['avgGDP'],ascending = False,inplace=True)
  return info.iloc[5]['2015']-info.iloc[5]['2006']

# %%
answer_four()
# Out:
# 246702696075.3999

# %%
##### Question 5 #####
# What is the mean energy supply per capita?
# This function should return a single number.

# %%
def answer_five():
  return df['Energy Supply per Capita'].mean()

# %%
answer_five()
# Out:
# 153.07142857142858

# %%
##### Question 6 #####
# What country:
# - has the maximum % Renewable
# - and what is the percentage?

# return:
# - a tuple with:
#    - the name of the country and 
#    - the percentage

# %%
def answer_six():
  result = df.sort_values(by='% Renewable', ascending=False).iloc[0]
  return result.name, result['% Renewable']

# %%
answer_six()
# Out:
# ('Brazil', 69.64803)

# %%
# Create:
# - a new column that:
#     - is the ratio of:
#       - Self-Citations
#       - to Total Citations
# - What is the maximum value for this new column?
# - and what country has the highest ratio?

# return a tuple with:
# - the name of the country
# - and the ratio.

# %%
def answer_seven():
  citation_ratio = df['Self-citations']/df['Citations']
  df.insert(3, 'citation_ratio', citation_ratio)
  result = df.sort_values(by='citation_ratio', ascending=False).iloc[0]
  return result.name, result['citation_ratio']

# %%
answer_seven()
# Out:
# ('China', 0.6893126179389422)

# %%
##### Question 8 ######
# Create a column that:
# - estimates the population using:
#   - Energy Supply 
#   - and Energy Supply per capita
# - What is the third most populous country according to this estimate?

# return:
# - name of the country

# %%
def anser_eight():
  population = df['Energy Supply per Capita'] * df['Energy Supply']
  df.insert(7, 'population', population)
  result = df.sort_values(by='population', ascending=False).iloc[0]
  return result.name

# %%
anser_eight()
# Out:
# 'United States'

# %%
### Question 9 ####
# Create a column that:
# - estimates the number of citable documents per person. 
# - What is the correlation between:
#   - the number of citable documents per capita
#   - and the energy supply per capita? 
# - Use the `.corr()` method, (Pearson's correlation).

# This function should return a single number.

# %%
def answer_nine():
  df = answer_one()
  df['PopEst'] = df['Energy Supply'] / df['Energy Supply per Capita']
  df['Citable docs per Capita'] = df['Citable documents'] / df['PopEst']
  return df['Citable docs per Capita'].astype(float).corr(df['Energy Supply per Capita'].astype(float))

# %%
#### Question 10 #####
